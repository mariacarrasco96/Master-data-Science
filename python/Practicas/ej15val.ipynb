# %% [markdown]
# # Ejercicios sobre diccionarios II + Ficheros

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# El fichero [localidades.txt]() contiene información de las localidades de la Comunidad de Madrid. Los datos que contiene son:
# * Nombre de la localidad
# * Teléfono Ayuntamiento
# * Teléfono Información
# * Teléfono emergencias
#
# Aunque los teléfonos pueden no aparecer todos en el fichero.
# Crear una función llamada __leer_datos__ que lea los datos del fichero y los almacene en una lista de líneas. Usa la operación __readlines__ de los ficheros. El parámetro de entrada de la función es la ruta donde se encuentra el fichero.
#
# La función debe devolver una lista con todos los municipio leídos en el fichero.
# ¿ Cuantos municipios hay en el fichero ?
#
# __Nota__
#
# Si da problemas la función `open`, usa el parámetro `encoding= "utf-8"`  para solucionarlo.

# %%
# Sol:  #Si tienes el fichero de localidades y la practica en el mismo fichero se puede ejecutar esta operacion
f = open('localidades.txt', encoding="utf8")
l = f.readlines()
l
# Out:
# ['Nombre localidad|Teléfono Ayuntamiento|Teléfono Información | Teléfono emergencias\n',
#  'La Acebeda|9286 |2855 |\n',
#  'Ajalvir||9097 |\n',
#  'El Álamo|9375 |8420 |\n',
#  'Alcalá de Henares|8350 ||7261 \n',
#  'Alcobendas||3115 |\n',
#  'Alcorcón|||9861 \n',
#  'Aldea del Fresno|||4043 \n',
#  'Alpedrete|1705 |6251 |2198 \n',
#  'Ambite||9037 |\n',
#  'Anchuelo|4973 |5257 |\n',
#  'Aranjuez||4805 |\n',
#  'Arganda del Rey|3111 ||3035 \n',
#  'Arroyomolinos|2926 ||8481 \n',
#  'El Atazar|9650 |7157 |\n',
#  'Batres|8800 |1164 |6059 \n',
#  'Becerril de la Sierra||7251 |1875 \n',
#  'Belmonte de Tajo|||3419 \n',
#  'El Berrueco|2476 ||6650 \n',
#  'Berzosa del Lozoya|4787 |2913 |2478 \n',
#  'Boadilla del Monte|1428 |5557 |\n',
#  'El Boalo|5632 |8008 |8019 \n',
#  'Brea de Tajo|||8496 \n',
#  'Brunete|3731 |8510 |\n',
#  'Buitrago del Lozoya|6917 |2243 |3178 \n',
#  'Bustarviejo||6323 |5048 \n',
#  'Cabanillas de la Sierra||8537 |\n',
#  'La Cabrera||7061 |\n',
#  'Cadalso de los Vidrios|1525 ||3811 \n',
#  'Camarma de Esteruelas||6306 |\n',
#  'Campo Real|5948 ||6869 \n',
#  'Canencia||3642 |\n',
#  'Carabaña|7429 |3229 |3824 \n',
#  'Casarrubuelos|||9868 \n',
#  'Cenicientos|||3535 \n',
#  'Cercedilla|5951 ||4381 \n',
#  'Cervera de Buitrago|8204 |7544 |7888 \n',
#  'Chapinería|3309 ||6356 \n',
#  'Chinchón||8625 |4951 \n',
#  'Ciempozuelos|9342 ||5329 \n',
#  'Cobeña|7469 |5442 |7997 \n',
#  'Collado Mediano|||3959 \n',
#  'Collado Villalba|6803 ||9073 \n',
#  'Colmenar de Oreja||1087 |7879 \n',
#  'Colmenar del Arroyo|2160 |8707 |\n',
#  'Colmenar Viejo|9666 ||\n',
#  'Coslada|1785 |1329 |4249 \n',
#  'Cubas de la Sagra|6723 ||\n',
#  'El Escorial||4217 |1383 \n',
#  'Estremera|5940 |2757 |1302 \n',
#  'Fresnedillas de la Oliva||3859 |1188 \n',
#  'Fresno de Torote||4211 |5417 \n',
#  'Fuenlabrada|||1792 \n',
#  'Fuente el Saz de Jarama||6708 |6663 \n',
#  'Fuentidueña de Tajo||2465 |5934 \n',
#  'Garganta de los Montes|9175 |2960 |\n',
#  'Gargantilla del Lozoya y Pinilla de Buitrago||2009 |1051 \n',
#  'Gascones||4412 |1008 \n',
#  'Getafe|3961 |2375 |\n',
#  'Griñón|1403 ||\n',
#  'Guadalix de la Sierra|8545 |7950 |\n',
#  'Guadarrama|4235 |8862 |\n',
#  'La Hiruela||3872 |5047 \n',
#  'Horcajo de la Sierra-Aoslos||2934 |\n',
#  'Horcajuelo de la Sierra||2301 |9201 \n',
#  'Hoyo de Manzanares|1957 ||1166 \n',
#  'Humanes de Madrid|||6626 \n',
#  'Leganés|6988 |4252 |\n',
#  'Loeches|4299 |8357 |\n',
#  'Lozoya||2105 |\n',
#  'Madarcos||9374 |4670 \n',
#  'Madrid||8364 |5654 \n',
#  'Majadahonda|6472 ||\n',
#  'Manzanares el Real|2722 ||\n',
#  'Meco|9795 |5167 |1371 \n',
#  'Mejorada del Campo||6626 |6207 \n',
#  'Miraflores de la Sierra|6707 ||8817 \n',
#  'El Molar|3917 |4017 |8453 \n',
#  'Montejo de la Sierra|8909 ||4449 \n',
#  'Moraleja de Enmedio|||8186 \n',
#  'Moralzarzal|8395 ||\n',
#  'Morata de Tajuña||6902 |2568 \n',
#  'Móstoles||7478 |\n',
#  'Navacerrada||4656 |1879 \n',
#  'Navalafuente|5930 |8503 |5025 \n',
#  'Navalagamella|8069 ||4266 \n',
#  'Navarredonda y San Mamés||8217 |9026 \n',
#  'Navas del Rey|1968 |1822 |\n',
#  'Nuevo Baztán|3921 |8820 |9022 \n',
#  'Olmeda de las Fuentes|1686 |9027 |6807 \n',
#  'Orusco de Tajuña|1441 |3232 |\n',
#  'Paracuellos de Jarama|2725 ||\n',
#  'Parla||7343 |\n',
#  'Patones|6989 |8254 |\n',
#  'Pedrezuela|6178 ||4419 \n',
#  'Pelayos de la Presa|4819 |7781 |\n',
#  'Perales de Tajuña|7083 |5941 |8831 \n',
#  'Pezuela de las Torres|9057 ||\n',
#  'Pinilla del Valle||7406 |\n',
#  'Pinto||4937 |9777 \n',
#  'Piñuécar-Gandullas|||3212 \n',
#  'Pozuelo de Alarcón|5020 |5677 |\n',
#  'Pozuelo del Rey|8517 |2681 |1992 \n',
#  'Prádena del Rincón|7311 ||\n',
#  'Puebla de la Sierra|8465 ||7208 \n',
#  'Puentes Viejas|4810 ||9311 \n',
#  'Quijorna|2955 |3847 |6584 \n',
#  'Rascafría||2517 |\n',
#  'Redueña|1697 |9153 |2294 \n',
#  'Ribatejada|7743 |7984 |\n',
#  'Rivas-Vaciamadrid|5772 ||8543 \n',
#  'Robledillo de la Jara|6010 |8884 |\n',
#  'Robledo de Chavela|3370 |3012 |1483 \n',
#  'Las Rozas de Madrid|4613 |8600 |\n',
#  'Rozas de Puerto Real|5923 ||\n',
#  'San Agustín del Guadalix|||7481 \n',
#  'San Fernando de Henares|9757 ||\n',
#  'San Lorenzo de El Escorial||8768 |4994 \n',
#  'San Martín de la Vega||8170 |9757 \n',
#  'San Martín de Valdeiglesias||7580 |7601 \n',
#  'San Sebastián de los Reyes|6214 |2003 |\n',
#  'Santa María de la Alameda|6150 |4360 |\n',
#  'La Serna del Monte||9793 |\n',
#  'Serranillos del Valle|6634 |4039 |5521 \n',
#  'Sevilla la Nueva||5915 |2169 \n',
#  'Somosierra|||8464 \n',
#  'Soto del Real|4957 |1931 |\n',
#  'Talamanca de Jarama||8877 |\n',
#  'Tielmes|1990 ||2548 \n',
#  'Torrejón de la Calzada|7768 ||\n',
#  'Torrejón de Velasco|3004 |2922 |\n',
#  'Torrelaguna|||1217 \n',
#  'Torrelodones|7985 |8890 |\n',
#  'Torres de la Alameda|||4479 \n',
#  'Tres Cantos|||7377 \n',
#  'Valdaracete|9116 ||\n',
#  'Valdeavero|||1588 \n',
#  'Valdelaguna|6780 ||9741 \n',
#  'Valdemanco||6281 |1655 \n',
#  'Valdemaqueda||7048 |7044 \n',
#  'Valdemorillo|5771 |9142 |\n',
#  'Valdemoro|8494 |2649 |6937 \n',
#  'Valdeolmos-Alalpardo|9798 ||\n',
#  'Valdepiélagos|2772 ||4486 \n',
#  'Valdetorres de Jarama|7714 |3833 |6464 \n',
#  'Valdilecha||7484 |\n',
#  'Valverde de Alcalá|8862 ||2659 \n',
#  'Velilla de San Antonio|4018 ||7163 \n',
#  'El Vellón|7021 ||1788 \n',
#  'Villa del Prado||6080 |\n',
#  'Villaconejos|5160 ||7071 \n',
#  'Villalbilla|5229 ||1291 \n',
#  'Villamanrique de Tajo|2573 ||7708 \n',
#  'Villamanta|6789 |8392 |9865 \n',
#  'Villamantilla|1031 |4450 |\n',
#  'Villanueva de la Cañada|5320 ||5261 \n',
#  'Villanueva de Perales|9567 ||6800 \n',
#  'Villanueva del Pardillo|||3241 \n',
#  'Villar del Olmo|9281 ||3595 \n',
#  'Villaviciosa de Odón|2647 |5440 |\n',
#  'Villavieja del Lozoya|5913 |8741 |5713 \n',
#  'Zarzalejo|5046 |1283 |\n']

# %%
def leer_localidades ():
    f = open('localidades.txt', encoding="utf8")
    l = f.readlines() #esta l es una lista de lineas, y de cada linea SOLO ME QUEDO CON EL MUNICIPIO
    localidades = []
    for linea in l[1:]:
        datos= linea.split("|")
        localidades.append (datos[0])
    return localidades
        
#lo que le estoy pidiendo es que me parta el stream cuando se encuentre |.

# %%
leer_localidades()
# Out:
# ['La Acebeda',
#  'Ajalvir',
#  'El Álamo',
#  'Alcalá de Henares',
#  'Alcobendas',
#  'Alcorcón',
#  'Aldea del Fresno',
#  'Alpedrete',
#  'Ambite',
#  'Anchuelo',
#  'Aranjuez',
#  'Arganda del Rey',
#  'Arroyomolinos',
#  'El Atazar',
#  'Batres',
#  'Becerril de la Sierra',
#  'Belmonte de Tajo',
#  'El Berrueco',
#  'Berzosa del Lozoya',
#  'Boadilla del Monte',
#  'El Boalo',
#  'Brea de Tajo',
#  'Brunete',
#  'Buitrago del Lozoya',
#  'Bustarviejo',
#  'Cabanillas de la Sierra',
#  'La Cabrera',
#  'Cadalso de los Vidrios',
#  'Camarma de Esteruelas',
#  'Campo Real',
#  'Canencia',
#  'Carabaña',
#  'Casarrubuelos',
#  'Cenicientos',
#  'Cercedilla',
#  'Cervera de Buitrago',
#  'Chapinería',
#  'Chinchón',
#  'Ciempozuelos',
#  'Cobeña',
#  'Collado Mediano',
#  'Collado Villalba',
#  'Colmenar de Oreja',
#  'Colmenar del Arroyo',
#  'Colmenar Viejo',
#  'Coslada',
#  'Cubas de la Sagra',
#  'El Escorial',
#  'Estremera',
#  'Fresnedillas de la Oliva',
#  'Fresno de Torote',
#  'Fuenlabrada',
#  'Fuente el Saz de Jarama',
#  'Fuentidueña de Tajo',
#  'Garganta de los Montes',
#  'Gargantilla del Lozoya y Pinilla de Buitrago',
#  'Gascones',
#  'Getafe',
#  'Griñón',
#  'Guadalix de la Sierra',
#  'Guadarrama',
#  'La Hiruela',
#  'Horcajo de la Sierra-Aoslos',
#  'Horcajuelo de la Sierra',
#  'Hoyo de Manzanares',
#  'Humanes de Madrid',
#  'Leganés',
#  'Loeches',
#  'Lozoya',
#  'Madarcos',
#  'Madrid',
#  'Majadahonda',
#  'Manzanares el Real',
#  'Meco',
#  'Mejorada del Campo',
#  'Miraflores de la Sierra',
#  'El Molar',
#  'Montejo de la Sierra',
#  'Moraleja de Enmedio',
#  'Moralzarzal',
#  'Morata de Tajuña',
#  'Móstoles',
#  'Navacerrada',
#  'Navalafuente',
#  'Navalagamella',
#  'Navarredonda y San Mamés',
#  'Navas del Rey',
#  'Nuevo Baztán',
#  'Olmeda de las Fuentes',
#  'Orusco de Tajuña',
#  'Paracuellos de Jarama',
#  'Parla',
#  'Patones',
#  'Pedrezuela',
#  'Pelayos de la Presa',
#  'Perales de Tajuña',
#  'Pezuela de las Torres',
#  'Pinilla del Valle',
#  'Pinto',
#  'Piñuécar-Gandullas',
#  'Pozuelo de Alarcón',
#  'Pozuelo del Rey',
#  'Prádena del Rincón',
#  'Puebla de la Sierra',
#  'Puentes Viejas',
#  'Quijorna',
#  'Rascafría',
#  'Redueña',
#  'Ribatejada',
#  'Rivas-Vaciamadrid',
#  'Robledillo de la Jara',
#  'Robledo de Chavela',
#  'Las Rozas de Madrid',
#  'Rozas de Puerto Real',
#  'San Agustín del Guadalix',
#  'San Fernando de Henares',
#  'San Lorenzo de El Escorial',
#  'San Martín de la Vega',
#  'San Martín de Valdeiglesias',
#  'San Sebastián de los Reyes',
#  'Santa María de la Alameda',
#  'La Serna del Monte',
#  'Serranillos del Valle',
#  'Sevilla la Nueva',
#  'Somosierra',
#  'Soto del Real',
#  'Talamanca de Jarama',
#  'Tielmes',
#  'Torrejón de la Calzada',
#  'Torrejón de Velasco',
#  'Torrelaguna',
#  'Torrelodones',
#  'Torres de la Alameda',
#  'Tres Cantos',
#  'Valdaracete',
#  'Valdeavero',
#  'Valdelaguna',
#  'Valdemanco',
#  'Valdemaqueda',
#  'Valdemorillo',
#  'Valdemoro',
#  'Valdeolmos-Alalpardo',
#  'Valdepiélagos',
#  'Valdetorres de Jarama',
#  'Valdilecha',
#  'Valverde de Alcalá',
#  'Velilla de San Antonio',
#  'El Vellón',
#  'Villa del Prado',
#  'Villaconejos',
#  'Villalbilla',
#  'Villamanrique de Tajo',
#  'Villamanta',
#  'Villamantilla',
#  'Villanueva de la Cañada',
#  'Villanueva de Perales',
#  'Villanueva del Pardillo',
#  'Villar del Olmo',
#  'Villaviciosa de Odón',
#  'Villavieja del Lozoya',
#  'Zarzalejo']

# %%
def leer_datos(lista):
    localidades = []
    i = 1
    while i < len(lista):
        x = lista[i].split('|')
        localidades.append(x[0:4])
        i = i + 1
    print(len(localidades))
    return (localidades)

# %%
localidades = leer_datos(l)
# Out:
# 161

# %%
type(localidades)
# Out:
# list

# %%
localidades
# Out:
# [['La Acebeda', '9286 ', '2855 ', '\n'],
#  ['Ajalvir', '', '9097 ', '\n'],
#  ['El Álamo', '9375 ', '8420 ', '\n'],
#  ['Alcalá de Henares', '8350 ', '', '7261 \n'],
#  ['Alcobendas', '', '3115 ', '\n'],
#  ['Alcorcón', '', '', '9861 \n'],
#  ['Aldea del Fresno', '', '', '4043 \n'],
#  ['Alpedrete', '1705 ', '6251 ', '2198 \n'],
#  ['Ambite', '', '9037 ', '\n'],
#  ['Anchuelo', '4973 ', '5257 ', '\n'],
#  ['Aranjuez', '', '4805 ', '\n'],
#  ['Arganda del Rey', '3111 ', '', '3035 \n'],
#  ['Arroyomolinos', '2926 ', '', '8481 \n'],
#  ['El Atazar', '9650 ', '7157 ', '\n'],
#  ['Batres', '8800 ', '1164 ', '6059 \n'],
#  ['Becerril de la Sierra', '', '7251 ', '1875 \n'],
#  ['Belmonte de Tajo', '', '', '3419 \n'],
#  ['El Berrueco', '2476 ', '', '6650 \n'],
#  ['Berzosa del Lozoya', '4787 ', '2913 ', '2478 \n'],
#  ['Boadilla del Monte', '1428 ', '5557 ', '\n'],
#  ['El Boalo', '5632 ', '8008 ', '8019 \n'],
#  ['Brea de Tajo', '', '', '8496 \n'],
#  ['Brunete', '3731 ', '8510 ', '\n'],
#  ['Buitrago del Lozoya', '6917 ', '2243 ', '3178 \n'],
#  ['Bustarviejo', '', '6323 ', '5048 \n'],
#  ['Cabanillas de la Sierra', '', '8537 ', '\n'],
#  ['La Cabrera', '', '7061 ', '\n'],
#  ['Cadalso de los Vidrios', '1525 ', '', '3811 \n'],
#  ['Camarma de Esteruelas', '', '6306 ', '\n'],
#  ['Campo Real', '5948 ', '', '6869 \n'],
#  ['Canencia', '', '3642 ', '\n'],
#  ['Carabaña', '7429 ', '3229 ', '3824 \n'],
#  ['Casarrubuelos', '', '', '9868 \n'],
#  ['Cenicientos', '', '', '3535 \n'],
#  ['Cercedilla', '5951 ', '', '4381 \n'],
#  ['Cervera de Buitrago', '8204 ', '7544 ', '7888 \n'],
#  ['Chapinería', '3309 ', '', '6356 \n'],
#  ['Chinchón', '', '8625 ', '4951 \n'],
#  ['Ciempozuelos', '9342 ', '', '5329 \n'],
#  ['Cobeña', '7469 ', '5442 ', '7997 \n'],
#  ['Collado Mediano', '', '', '3959 \n'],
#  ['Collado Villalba', '6803 ', '', '9073 \n'],
#  ['Colmenar de Oreja', '', '1087 ', '7879 \n'],
#  ['Colmenar del Arroyo', '2160 ', '8707 ', '\n'],
#  ['Colmenar Viejo', '9666 ', '', '\n'],
#  ['Coslada', '1785 ', '1329 ', '4249 \n'],
#  ['Cubas de la Sagra', '6723 ', '', '\n'],
#  ['El Escorial', '', '4217 ', '1383 \n'],
#  ['Estremera', '5940 ', '2757 ', '1302 \n'],
#  ['Fresnedillas de la Oliva', '', '3859 ', '1188 \n'],
#  ['Fresno de Torote', '', '4211 ', '5417 \n'],
#  ['Fuenlabrada', '', '', '1792 \n'],
#  ['Fuente el Saz de Jarama', '', '6708 ', '6663 \n'],
#  ['Fuentidueña de Tajo', '', '2465 ', '5934 \n'],
#  ['Garganta de los Montes', '9175 ', '2960 ', '\n'],
#  ['Gargantilla del Lozoya y Pinilla de Buitrago', '', '2009 ', '1051 \n'],
#  ['Gascones', '', '4412 ', '1008 \n'],
#  ['Getafe', '3961 ', '2375 ', '\n'],
#  ['Griñón', '1403 ', '', '\n'],
#  ['Guadalix de la Sierra', '8545 ', '7950 ', '\n'],
#  ['Guadarrama', '4235 ', '8862 ', '\n'],
#  ['La Hiruela', '', '3872 ', '5047 \n'],
#  ['Horcajo de la Sierra-Aoslos', '', '2934 ', '\n'],
#  ['Horcajuelo de la Sierra', '', '2301 ', '9201 \n'],
#  ['Hoyo de Manzanares', '1957 ', '', '1166 \n'],
#  ['Humanes de Madrid', '', '', '6626 \n'],
#  ['Leganés', '6988 ', '4252 ', '\n'],
#  ['Loeches', '4299 ', '8357 ', '\n'],
#  ['Lozoya', '', '2105 ', '\n'],
#  ['Madarcos', '', '9374 ', '4670 \n'],
#  ['Madrid', '', '8364 ', '5654 \n'],
#  ['Majadahonda', '6472 ', '', '\n'],
#  ['Manzanares el Real', '2722 ', '', '\n'],
#  ['Meco', '9795 ', '5167 ', '1371 \n'],
#  ['Mejorada del Campo', '', '6626 ', '6207 \n'],
#  ['Miraflores de la Sierra', '6707 ', '', '8817 \n'],
#  ['El Molar', '3917 ', '4017 ', '8453 \n'],
#  ['Montejo de la Sierra', '8909 ', '', '4449 \n'],
#  ['Moraleja de Enmedio', '', '', '8186 \n'],
#  ['Moralzarzal', '8395 ', '', '\n'],
#  ['Morata de Tajuña', '', '6902 ', '2568 \n'],
#  ['Móstoles', '', '7478 ', '\n'],
#  ['Navacerrada', '', '4656 ', '1879 \n'],
#  ['Navalafuente', '5930 ', '8503 ', '5025 \n'],
#  ['Navalagamella', '8069 ', '', '4266 \n'],
#  ['Navarredonda y San Mamés', '', '8217 ', '9026 \n'],
#  ['Navas del Rey', '1968 ', '1822 ', '\n'],
#  ['Nuevo Baztán', '3921 ', '8820 ', '9022 \n'],
#  ['Olmeda de las Fuentes', '1686 ', '9027 ', '6807 \n'],
#  ['Orusco de Tajuña', '1441 ', '3232 ', '\n'],
#  ['Paracuellos de Jarama', '2725 ', '', '\n'],
#  ['Parla', '', '7343 ', '\n'],
#  ['Patones', '6989 ', '8254 ', '\n'],
#  ['Pedrezuela', '6178 ', '', '4419 \n'],
#  ['Pelayos de la Presa', '4819 ', '7781 ', '\n'],
#  ['Perales de Tajuña', '7083 ', '5941 ', '8831 \n'],
#  ['Pezuela de las Torres', '9057 ', '', '\n'],
#  ['Pinilla del Valle', '', '7406 ', '\n'],
#  ['Pinto', '', '4937 ', '9777 \n'],
#  ['Piñuécar-Gandullas', '', '', '3212 \n'],
#  ['Pozuelo de Alarcón', '5020 ', '5677 ', '\n'],
#  ['Pozuelo del Rey', '8517 ', '2681 ', '1992 \n'],
#  ['Prádena del Rincón', '7311 ', '', '\n'],
#  ['Puebla de la Sierra', '8465 ', '', '7208 \n'],
#  ['Puentes Viejas', '4810 ', '', '9311 \n'],
#  ['Quijorna', '2955 ', '3847 ', '6584 \n'],
#  ['Rascafría', '', '2517 ', '\n'],
#  ['Redueña', '1697 ', '9153 ', '2294 \n'],
#  ['Ribatejada', '7743 ', '7984 ', '\n'],
#  ['Rivas-Vaciamadrid', '5772 ', '', '8543 \n'],
#  ['Robledillo de la Jara', '6010 ', '8884 ', '\n'],
#  ['Robledo de Chavela', '3370 ', '3012 ', '1483 \n'],
#  ['Las Rozas de Madrid', '4613 ', '8600 ', '\n'],
#  ['Rozas de Puerto Real', '5923 ', '', '\n'],
#  ['San Agustín del Guadalix', '', '', '7481 \n'],
#  ['San Fernando de Henares', '9757 ', '', '\n'],
#  ['San Lorenzo de El Escorial', '', '8768 ', '4994 \n'],
#  ['San Martín de la Vega', '', '8170 ', '9757 \n'],
#  ['San Martín de Valdeiglesias', '', '7580 ', '7601 \n'],
#  ['San Sebastián de los Reyes', '6214 ', '2003 ', '\n'],
#  ['Santa María de la Alameda', '6150 ', '4360 ', '\n'],
#  ['La Serna del Monte', '', '9793 ', '\n'],
#  ['Serranillos del Valle', '6634 ', '4039 ', '5521 \n'],
#  ['Sevilla la Nueva', '', '5915 ', '2169 \n'],
#  ['Somosierra', '', '', '8464 \n'],
#  ['Soto del Real', '4957 ', '1931 ', '\n'],
#  ['Talamanca de Jarama', '', '8877 ', '\n'],
#  ['Tielmes', '1990 ', '', '2548 \n'],
#  ['Torrejón de la Calzada', '7768 ', '', '\n'],
#  ['Torrejón de Velasco', '3004 ', '2922 ', '\n'],
#  ['Torrelaguna', '', '', '1217 \n'],
#  ['Torrelodones', '7985 ', '8890 ', '\n'],
#  ['Torres de la Alameda', '', '', '4479 \n'],
#  ['Tres Cantos', '', '', '7377 \n'],
#  ['Valdaracete', '9116 ', '', '\n'],
#  ['Valdeavero', '', '', '1588 \n'],
#  ['Valdelaguna', '6780 ', '', '9741 \n'],
#  ['Valdemanco', '', '6281 ', '1655 \n'],
#  ['Valdemaqueda', '', '7048 ', '7044 \n'],
#  ['Valdemorillo', '5771 ', '9142 ', '\n'],
#  ['Valdemoro', '8494 ', '2649 ', '6937 \n'],
#  ['Valdeolmos-Alalpardo', '9798 ', '', '\n'],
#  ['Valdepiélagos', '2772 ', '', '4486 \n'],
#  ['Valdetorres de Jarama', '7714 ', '3833 ', '6464 \n'],
#  ['Valdilecha', '', '7484 ', '\n'],
#  ['Valverde de Alcalá', '8862 ', '', '2659 \n'],
#  ['Velilla de San Antonio', '4018 ', '', '7163 \n'],
#  ['El Vellón', '7021 ', '', '1788 \n'],
#  ['Villa del Prado', '', '6080 ', '\n'],
#  ['Villaconejos', '5160 ', '', '7071 \n'],
#  ['Villalbilla', '5229 ', '', '1291 \n'],
#  ['Villamanrique de Tajo', '2573 ', '', '7708 \n'],
#  ['Villamanta', '6789 ', '8392 ', '9865 \n'],
#  ['Villamantilla', '1031 ', '4450 ', '\n'],
#  ['Villanueva de la Cañada', '5320 ', '', '5261 \n'],
#  ['Villanueva de Perales', '9567 ', '', '6800 \n'],
#  ['Villanueva del Pardillo', '', '', '3241 \n'],
#  ['Villar del Olmo', '9281 ', '', '3595 \n'],
#  ['Villaviciosa de Odón', '2647 ', '5440 ', '\n'],
#  ['Villavieja del Lozoya', '5913 ', '8741 ', '5713 \n'],
#  ['Zarzalejo', '5046 ', '1283 ', '\n']]

# %% [markdown]
# ## Ejercicio 2

# %% [markdown]
# Escribe una función llamada __crear_agenda__ para crear la agenda de los teléfonos de los municipios de la Comunidad de Madrid.
# La función tiene un único parámetro de entrada, que es la lista de municipios devuelta por la función del Ejercicio 1.
#
# El valor devuelto por la función __crear_agenda__ es de tipo diccionario, donde las claves son los nombres de los municipios y el valor asociado a cada clave será otro diccionario con tantas claves como teléfonos disponibles tenga el municipio.
#
# __Notas:__
# La función deve devolver un diccionario con el siguiente aspecto:
#
# ```
# {
#  'La Acebeda': {'Teléfono Ayuntamiento': '9286',   'Teléfono Información': '2855'},
#  'Ajalvir': {'Teléfono Información': '9097'},
#  'El Álamo': {'Teléfono Ayuntamiento': '9375', 'Teléfono Información': '8420'},
#  'Alcalá de Henares': {'Teléfono Ayuntamiento': '8350',   'Teléfono Emergencias': '7261'},
#  'Alcobendas': {'Teléfono Información': '3115'},
#     ...
#     ...
#  'Zarzalejo': {'Teléfono Ayuntamiento': '5046',  'Teléfono Información': '1283'}
# }
# ```

# %%
d = "  Mostoles  "
d.strip()
#Para quitar los espacios en blanco. los de la derecha d.dstrip. los de la izq d.lstrip. 
#tambien me quita los saltos de linea
# Out:
# 'Mostoles'

# %%
def crear_agenda_localidades ():
    f = open('localidades.txt', encoding="utf8")
    l = f.readlines()
    agenda = {}
    for linea in l [1:]: 
        datos = linea.split("|")
        nombre = datos[0].strip() #strip: elimina saltos, espacios 
        ayunta = datos[1].strip()
        inf = datos[2].strip()
        emer = datos [3].strip()
        agenda[nombre] = {}
        if ayunta != "":
            agenda [nombre]["tel ayunt"] = ayunta 
            agenda [nombre]["tel inf"] = inf
    
    
    return agenda

# %%
agenda_municipios = crear_agenda_localidades()
agenda_municipios
# Out:
# {'La Acebeda': {'tel ayunt': '9286', 'tel inf': '2855'},
#  'Ajalvir': {},
#  'El Álamo': {'tel ayunt': '9375', 'tel inf': '8420'},
#  'Alcalá de Henares': {'tel ayunt': '8350', 'tel inf': ''},
#  'Alcobendas': {},
#  'Alcorcón': {},
#  'Aldea del Fresno': {},
#  'Alpedrete': {'tel ayunt': '1705', 'tel inf': '6251'},
#  'Ambite': {},
#  'Anchuelo': {'tel ayunt': '4973', 'tel inf': '5257'},
#  'Aranjuez': {},
#  'Arganda del Rey': {'tel ayunt': '3111', 'tel inf': ''},
#  'Arroyomolinos': {'tel ayunt': '2926', 'tel inf': ''},
#  'El Atazar': {'tel ayunt': '9650', 'tel inf': '7157'},
#  'Batres': {'tel ayunt': '8800', 'tel inf': '1164'},
#  'Becerril de la Sierra': {},
#  'Belmonte de Tajo': {},
#  'El Berrueco': {'tel ayunt': '2476', 'tel inf': ''},
#  'Berzosa del Lozoya': {'tel ayunt': '4787', 'tel inf': '2913'},
#  'Boadilla del Monte': {'tel ayunt': '1428', 'tel inf': '5557'},
#  'El Boalo': {'tel ayunt': '5632', 'tel inf': '8008'},
#  'Brea de Tajo': {},
#  'Brunete': {'tel ayunt': '3731', 'tel inf': '8510'},
#  'Buitrago del Lozoya': {'tel ayunt': '6917', 'tel inf': '2243'},
#  'Bustarviejo': {},
#  'Cabanillas de la Sierra': {},
#  'La Cabrera': {},
#  'Cadalso de los Vidrios': {'tel ayunt': '1525', 'tel inf': ''},
#  'Camarma de Esteruelas': {},
#  'Campo Real': {'tel ayunt': '5948', 'tel inf': ''},
#  'Canencia': {},
#  'Carabaña': {'tel ayunt': '7429', 'tel inf': '3229'},
#  'Casarrubuelos': {},
#  'Cenicientos': {},
#  'Cercedilla': {'tel ayunt': '5951', 'tel inf': ''},
#  'Cervera de Buitrago': {'tel ayunt': '8204', 'tel inf': '7544'},
#  'Chapinería': {'tel ayunt': '3309', 'tel inf': ''},
#  'Chinchón': {},
#  'Ciempozuelos': {'tel ayunt': '9342', 'tel inf': ''},
#  'Cobeña': {'tel ayunt': '7469', 'tel inf': '5442'},
#  'Collado Mediano': {},
#  'Collado Villalba': {'tel ayunt': '6803', 'tel inf': ''},
#  'Colmenar de Oreja': {},
#  'Colmenar del Arroyo': {'tel ayunt': '2160', 'tel inf': '8707'},
#  'Colmenar Viejo': {'tel ayunt': '9666', 'tel inf': ''},
#  'Coslada': {'tel ayunt': '1785', 'tel inf': '1329'},
#  'Cubas de la Sagra': {'tel ayunt': '6723', 'tel inf': ''},
#  'El Escorial': {},
#  'Estremera': {'tel ayunt': '5940', 'tel inf': '2757'},
#  'Fresnedillas de la Oliva': {},
#  'Fresno de Torote': {},
#  'Fuenlabrada': {},
#  'Fuente el Saz de Jarama': {},
#  'Fuentidueña de Tajo': {},
#  'Garganta de los Montes': {'tel ayunt': '9175', 'tel inf': '2960'},
#  'Gargantilla del Lozoya y Pinilla de Buitrago': {},
#  'Gascones': {},
#  'Getafe': {'tel ayunt': '3961', 'tel inf': '2375'},
#  'Griñón': {'tel ayunt': '1403', 'tel inf': ''},
#  'Guadalix de la Sierra': {'tel ayunt': '8545', 'tel inf': '7950'},
#  'Guadarrama': {'tel ayunt': '4235', 'tel inf': '8862'},
#  'La Hiruela': {},
#  'Horcajo de la Sierra-Aoslos': {},
#  'Horcajuelo de la Sierra': {},
#  'Hoyo de Manzanares': {'tel ayunt': '1957', 'tel inf': ''},
#  'Humanes de Madrid': {},
#  'Leganés': {'tel ayunt': '6988', 'tel inf': '4252'},
#  'Loeches': {'tel ayunt': '4299', 'tel inf': '8357'},
#  'Lozoya': {},
#  'Madarcos': {},
#  'Madrid': {},
#  'Majadahonda': {'tel ayunt': '6472', 'tel inf': ''},
#  'Manzanares el Real': {'tel ayunt': '2722', 'tel inf': ''},
#  'Meco': {'tel ayunt': '9795', 'tel inf': '5167'},
#  'Mejorada del Campo': {},
#  'Miraflores de la Sierra': {'tel ayunt': '6707', 'tel inf': ''},
#  'El Molar': {'tel ayunt': '3917', 'tel inf': '4017'},
#  'Montejo de la Sierra': {'tel ayunt': '8909', 'tel inf': ''},
#  'Moraleja de Enmedio': {},
#  'Moralzarzal': {'tel ayunt': '8395', 'tel inf': ''},
#  'Morata de Tajuña': {},
#  'Móstoles': {},
#  'Navacerrada': {},
#  'Navalafuente': {'tel ayunt': '5930', 'tel inf': '8503'},
#  'Navalagamella': {'tel ayunt': '8069', 'tel inf': ''},
#  'Navarredonda y San Mamés': {},
#  'Navas del Rey': {'tel ayunt': '1968', 'tel inf': '1822'},
#  'Nuevo Baztán': {'tel ayunt': '3921', 'tel inf': '8820'},
#  'Olmeda de las Fuentes': {'tel ayunt': '1686', 'tel inf': '9027'},
#  'Orusco de Tajuña': {'tel ayunt': '1441', 'tel inf': '3232'},
#  'Paracuellos de Jarama': {'tel ayunt': '2725', 'tel inf': ''},
#  'Parla': {},
#  'Patones': {'tel ayunt': '6989', 'tel inf': '8254'},
#  'Pedrezuela': {'tel ayunt': '6178', 'tel inf': ''},
#  'Pelayos de la Presa': {'tel ayunt': '4819', 'tel inf': '7781'},
#  'Perales de Tajuña': {'tel ayunt': '7083', 'tel inf': '5941'},
#  'Pezuela de las Torres': {'tel ayunt': '9057', 'tel inf': ''},
#  'Pinilla del Valle': {},
#  'Pinto': {},
#  'Piñuécar-Gandullas': {},
#  'Pozuelo de Alarcón': {'tel ayunt': '5020', 'tel inf': '5677'},
#  'Pozuelo del Rey': {'tel ayunt': '8517', 'tel inf': '2681'},
#  'Prádena del Rincón': {'tel ayunt': '7311', 'tel inf': ''},
#  'Puebla de la Sierra': {'tel ayunt': '8465', 'tel inf': ''},
#  'Puentes Viejas': {'tel ayunt': '4810', 'tel inf': ''},
#  'Quijorna': {'tel ayunt': '2955', 'tel inf': '3847'},
#  'Rascafría': {},
#  'Redueña': {'tel ayunt': '1697', 'tel inf': '9153'},
#  'Ribatejada': {'tel ayunt': '7743', 'tel inf': '7984'},
#  'Rivas-Vaciamadrid': {'tel ayunt': '5772', 'tel inf': ''},
#  'Robledillo de la Jara': {'tel ayunt': '6010', 'tel inf': '8884'},
#  'Robledo de Chavela': {'tel ayunt': '3370', 'tel inf': '3012'},
#  'Las Rozas de Madrid': {'tel ayunt': '4613', 'tel inf': '8600'},
#  'Rozas de Puerto Real': {'tel ayunt': '5923', 'tel inf': ''},
#  'San Agustín del Guadalix': {},
#  'San Fernando de Henares': {'tel ayunt': '9757', 'tel inf': ''},
#  'San Lorenzo de El Escorial': {},
#  'San Martín de la Vega': {},
#  'San Martín de Valdeiglesias': {},
#  'San Sebastián de los Reyes': {'tel ayunt': '6214', 'tel inf': '2003'},
#  'Santa María de la Alameda': {'tel ayunt': '6150', 'tel inf': '4360'},
#  'La Serna del Monte': {},
#  'Serranillos del Valle': {'tel ayunt': '6634', 'tel inf': '4039'},
#  'Sevilla la Nueva': {},
#  'Somosierra': {},
#  'Soto del Real': {'tel ayunt': '4957', 'tel inf': '1931'},
#  'Talamanca de Jarama': {},
#  'Tielmes': {'tel ayunt': '1990', 'tel inf': ''},
#  'Torrejón de la Calzada': {'tel ayunt': '7768', 'tel inf': ''},
#  'Torrejón de Velasco': {'tel ayunt': '3004', 'tel inf': '2922'},
#  'Torrelaguna': {},
#  'Torrelodones': {'tel ayunt': '7985', 'tel inf': '8890'},
#  'Torres de la Alameda': {},
#  'Tres Cantos': {},
#  'Valdaracete': {'tel ayunt': '9116', 'tel inf': ''},
#  'Valdeavero': {},
#  'Valdelaguna': {'tel ayunt': '6780', 'tel inf': ''},
#  'Valdemanco': {},
#  'Valdemaqueda': {},
#  'Valdemorillo': {'tel ayunt': '5771', 'tel inf': '9142'},
#  'Valdemoro': {'tel ayunt': '8494', 'tel inf': '2649'},
#  'Valdeolmos-Alalpardo': {'tel ayunt': '9798', 'tel inf': ''},
#  'Valdepiélagos': {'tel ayunt': '2772', 'tel inf': ''},
#  'Valdetorres de Jarama': {'tel ayunt': '7714', 'tel inf': '3833'},
#  'Valdilecha': {},
#  'Valverde de Alcalá': {'tel ayunt': '8862', 'tel inf': ''},
#  'Velilla de San Antonio': {'tel ayunt': '4018', 'tel inf': ''},
#  'El Vellón': {'tel ayunt': '7021', 'tel inf': ''},
#  'Villa del Prado': {},
#  'Villaconejos': {'tel ayunt': '5160', 'tel inf': ''},
#  'Villalbilla': {'tel ayunt': '5229', 'tel inf': ''},
#  'Villamanrique de Tajo': {'tel ayunt': '2573', 'tel inf': ''},
#  'Villamanta': {'tel ayunt': '6789', 'tel inf': '8392'},
#  'Villamantilla': {'tel ayunt': '1031', 'tel inf': '4450'},
#  'Villanueva de la Cañada': {'tel ayunt': '5320', 'tel inf': ''},
#  'Villanueva de Perales': {'tel ayunt': '9567', 'tel inf': ''},
#  'Villanueva del Pardillo': {},
#  'Villar del Olmo': {'tel ayunt': '9281', 'tel inf': ''},
#  'Villaviciosa de Odón': {'tel ayunt': '2647', 'tel inf': '5440'},
#  'Villavieja del Lozoya': {'tel ayunt': '5913', 'tel inf': '8741'},
#  'Zarzalejo': {'tel ayunt': '5046', 'tel inf': '1283'}}

# %% [markdown]
# ## Ejercicio 3

# %% [markdown]
# Escribe una función en Python llamada __consulta_telefono__ para recuperar los teléfonos disponibles de un municipio.
# La función tiene dos argumentos de entrada:
# 1. Agenda de municipios creada por la función del ejercicio 2.
# 2. Nombre de un municipio
#
# Si el nombre del municipio  no se encuentra en el diccionario, la función devuelve el valor `False`. En caso contrario, devuelve un diccionario con los teléfonos disponibles.
#
# __Ejemplo de ejecución:__
#
# ```
# In:
#     t = consulta_telefono('Zarzalejo', agenda_municipios)
#     t
# Out:
#     {'Teléfono Ayuntamiento': '5046',  'Teléfono Información': '1283'}
# ```

# %%
def consulta_telefono(municipio,agenda):
    if municipio in agenda:
        return agenda[municipio]
    else:
        return False

# %%
t = consulta_telefono('Zarzalejo', agenda_municipios)
t
# Out:
# {'tel ayunt': '5046', 'tel inf': '1283'}

# %% [markdown]
# ## Ejercicio 4

# %% [markdown]
# Escribe una función en Python llamada __consulta_tipo_telef__ para recuperar número de teléfono de un determinado tipo (Emergencias, Ayuntamiento o Información) de un municipio.
# La función tiene tres argumentos de entrada:
# 1. Agenda de los municipios
# 2. Nombre de un municipio
# 3. Tipo de número de teléfono
#
# Si el municipio no se encuentra en la agenda, la función devuelve el valor `False`. En caso contrario, devuelve su número de teléfono. Si el tipo de teléfono no existe para ese amigo, la función devuelve el valor `False`.
#
# __Ejemplo de ejecución 1 :__
#
# ```
# In:
#     t =  consulta_tipo_telefono('Zarzalejo', 'Teléfono Ayuntamiento', agenda_municipios)
#     t
# Out:
#     5046
# ```
# __Ejemplo de ejecución 2 :__
# ```
# In:
#     t =  consulta_tipo_telefono('Zarzalejo', 'Teléfono Piscina', agenda_municipios)
#     t
# Out:
#     False
# ```

# %%
def consulta_tipo_telefono(municipio, tipo_telefono, agenda):
    if municipio in agenda and tipo_telefono in agenda[municipio]:

        return agenda[municipio][tipo_telefono]
    else:
        return False

# %%
consulta_tipo_telefono('Zarzalejo', 'Teléfono Piscina', agenda_municipios)
# Out:
# False

# %% [markdown]
# ## Ejercicio 5

# %% [markdown]
# Escribe una función en Python llamada __lista_municipios__ para recuperar los nombres de los municipios que se encuentrasn registrados en la agenda de teléfonos.
# La función tiene un único argumento de entrada:
# 1. Diccionario que representa la agenda
#
# La función ha de devolver una lista ordenada de municipios en orden lexicográfico.
#
# __Ejemplo de ejecución:__
# ```
# In:
#     a = lista_municipios(agenda)
#     a
# Out:
#     ['Ajalvir',
#      'Alcalá de Henares',
#      'Alcobendas',
#      ...
#      'Zarzalejo']
#
# ```

# %%
def lista_municipios(agenda):
    a = sorted(list(agenda))
    return a

# %%
lista_municipios(agenda_municipios)
# Out:
# ['Ajalvir',
#  'Alcalá de Henares',
#  'Alcobendas',
#  'Alcorcón',
#  'Aldea del Fresno',
#  'Alpedrete',
#  'Ambite',
#  'Anchuelo',
#  'Aranjuez',
#  'Arganda del Rey',
#  'Arroyomolinos',
#  'Batres',
#  'Becerril de la Sierra',
#  'Belmonte de Tajo',
#  'Berzosa del Lozoya',
#  'Boadilla del Monte',
#  'Brea de Tajo',
#  'Brunete',
#  'Buitrago del Lozoya',
#  'Bustarviejo',
#  'Cabanillas de la Sierra',
#  'Cadalso de los Vidrios',
#  'Camarma de Esteruelas',
#  'Campo Real',
#  'Canencia',
#  'Carabaña',
#  'Casarrubuelos',
#  'Cenicientos',
#  'Cercedilla',
#  'Cervera de Buitrago',
#  'Chapinería',
#  'Chinchón',
#  'Ciempozuelos',
#  'Cobeña',
#  'Collado Mediano',
#  'Collado Villalba',
#  'Colmenar Viejo',
#  'Colmenar de Oreja',
#  'Colmenar del Arroyo',
#  'Coslada',
#  'Cubas de la Sagra',
#  'El Atazar',
#  'El Berrueco',
#  'El Boalo',
#  'El Escorial',
#  'El Molar',
#  'El Vellón',
#  'El Álamo',
#  'Estremera',
#  'Fresnedillas de la Oliva',
#  'Fresno de Torote',
#  'Fuenlabrada',
#  'Fuente el Saz de Jarama',
#  'Fuentidueña de Tajo',
#  'Garganta de los Montes',
#  'Gargantilla del Lozoya y Pinilla de Buitrago',
#  'Gascones',
#  'Getafe',
#  'Griñón',
#  'Guadalix de la Sierra',
#  'Guadarrama',
#  'Horcajo de la Sierra-Aoslos',
#  'Horcajuelo de la Sierra',
#  'Hoyo de Manzanares',
#  'Humanes de Madrid',
#  'La Acebeda',
#  'La Cabrera',
#  'La Hiruela',
#  'La Serna del Monte',
#  'Las Rozas de Madrid',
#  'Leganés',
#  'Loeches',
#  'Lozoya',
#  'Madarcos',
#  'Madrid',
#  'Majadahonda',
#  'Manzanares el Real',
#  'Meco',
#  'Mejorada del Campo',
#  'Miraflores de la Sierra',
#  'Montejo de la Sierra',
#  'Moraleja de Enmedio',
#  'Moralzarzal',
#  'Morata de Tajuña',
#  'Móstoles',
#  'Navacerrada',
#  'Navalafuente',
#  'Navalagamella',
#  'Navarredonda y San Mamés',
#  'Navas del Rey',
#  'Nuevo Baztán',
#  'Olmeda de las Fuentes',
#  'Orusco de Tajuña',
#  'Paracuellos de Jarama',
#  'Parla',
#  'Patones',
#  'Pedrezuela',
#  'Pelayos de la Presa',
#  'Perales de Tajuña',
#  'Pezuela de las Torres',
#  'Pinilla del Valle',
#  'Pinto',
#  'Piñuécar-Gandullas',
#  'Pozuelo de Alarcón',
#  'Pozuelo del Rey',
#  'Prádena del Rincón',
#  'Puebla de la Sierra',
#  'Puentes Viejas',
#  'Quijorna',
#  'Rascafría',
#  'Redueña',
#  'Ribatejada',
#  'Rivas-Vaciamadrid',
#  'Robledillo de la Jara',
#  'Robledo de Chavela',
#  'Rozas de Puerto Real',
#  'San Agustín del Guadalix',
#  'San Fernando de Henares',
#  'San Lorenzo de El Escorial',
#  'San Martín de Valdeiglesias',
#  'San Martín de la Vega',
#  'San Sebastián de los Reyes',
#  'Santa María de la Alameda',
#  'Serranillos del Valle',
#  'Sevilla la Nueva',
#  'Somosierra',
#  'Soto del Real',
#  'Talamanca de Jarama',
#  'Tielmes',
#  'Torrejón de Velasco',
#  'Torrejón de la Calzada',
#  'Torrelaguna',
#  'Torrelodones',
#  'Torres de la Alameda',
#  'Tres Cantos',
#  'Valdaracete',
#  'Valdeavero',
#  'Valdelaguna',
#  'Valdemanco',
#  'Valdemaqueda',
#  'Valdemorillo',
#  'Valdemoro',
#  'Valdeolmos-Alalpardo',
#  'Valdepiélagos',
#  'Valdetorres de Jarama',
#  'Valdilecha',
#  'Valverde de Alcalá',
#  'Velilla de San Antonio',
#  'Villa del Prado',
#  'Villaconejos',
#  'Villalbilla',
#  'Villamanrique de Tajo',
#  'Villamanta',
#  'Villamantilla',
#  'Villanueva de Perales',
#  'Villanueva de la Cañada',
#  'Villanueva del Pardillo',
#  'Villar del Olmo',
#  'Villaviciosa de Odón',
#  'Villavieja del Lozoya',
#  'Zarzalejo']

# %% [markdown]
# ## Ejercicio 6

# %% [markdown]
# Escribe una función en Python llamada __eliminar_municipio__ para eliminar los datos de un municipio de una agenda de teléfonos. Dicha agenda se representa como un diccionario.
# La función tiene tres  argumentos de entrada:
# 1. Diccionario que representa la agenda
# 2. El nombre de un municipio
#
# La función devuelve el valor `True` si se ha eliminado correctamente. Devuelve False para indicar que el municipio no estaba en la agenda.

# %%
def eliminar_municipio(agenda, municipio):
    if municipio in agenda:
        agenda.pop(municipio)
        return True
    else:
        return False

# %%
eliminar_municipio(agenda_municipios, 'Alcalá de Henares')
# Out:
# True

# %%
eliminar_municipio(agenda_municipios, 'Vera')
# Out:
# False
