# %% [markdown]
# # Loan

# %% [markdown]
# El dataset [./dataset/loan2.csv](./dataset/loan2.csv) contiene ciertos registros relacionados con préstamos. Cada registro se corresponde con los datos de un préstamo.

# %% [markdown]
# __1.)__  Crear un DataFrame llamado `loan` con los datos del fichero. No te olvides de importar el módulo necesario para realizar la creación del DataFrame.

# %%
# Sol:
import pandas as pd
loan = pd.read_csv('./datos/loan2.csv ')
loan.head()

# %% [markdown]
# __2.)__ Muestra las últimas filas del DataFrame que has creado en el apartado anterior.

# %%
# Sol: 
loan.tail()
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 3240  50253711   53632438     7150.0       7150.0           7150.0
# 3241  15680685   17773104     5000.0       5000.0           5000.0
# 3242  10105780   11957868    35000.0      35000.0          34900.0
# 3243  16091841   18194317    13825.0      13825.0          13825.0
# 3244  19927712   22150395    21000.0      21000.0          21000.0
#
#             term  int_rate  installment grade sub_grade     ...       \
# 3240   36 months     11.53       235.89     B        B5     ...
# 3241   36 months     12.49       167.25     B        B5     ...
# 3242   36 months     11.99      1162.34     B        B3     ...
# 3243   36 months     20.20       515.20     E        E3     ...
# 3244   36 months     10.15       679.10     B        B2     ...
#
#      total_bal_il il_util open_rv_12m  open_rv_24m max_bal_bc all_util  \
# 3240          NaN     NaN         NaN          NaN        NaN      NaN
# ...

# %% [markdown]
# __3.)__ ¿Cuántas filas tiene la tabla?

# %%
# Sol
loan.shape
# Out:
# (3245, 74)

# %% [markdown]
# __4.)__  Crea otro dataframe llamado `loan2` con los datos del fichero, pero esta vez realiza la carga únicamente de las siguientes columnas:

# %% [markdown]
# ```cols = ['member_id', 'loan_amnt', 'term' , 'int_rate', 'purpose',
#          'application_type' , 'addr_state', 'annual_inc',
#          'loan_status' ]```

# %%
# Sol: 
cols = ['member_id', 'loan_amnt', 'term' , 'int_rate', 'purpose', 
         'application_type' , 'addr_state', 'annual_inc',
         'loan_status' ]


loan = pd.read_csv('./dataset/loan2.csv ', 
                  usecols = cols)
loan
# Out:
#       member_id  loan_amnt        term  int_rate  annual_inc  loan_status  \
# 0      64972117    25000.0   36 months     13.33    80000.00      Current
# 1      46666131    11200.0   60 months     16.55    31500.00      Current
# 2      66473639     6000.0   36 months     12.69    45000.00      Current
# 3      28500374    10000.0   60 months     12.99    40000.00      Current
# 4        996162     5000.0   36 months     11.49    75000.00   Fully Paid
# 5      60234745    24000.0   36 months     16.55    58000.00      Current
# 6      70418926     5000.0   36 months     10.64    35000.00      Current
# 7      28450964    15000.0   36 months     11.67    62000.00      Current
# 8      66333916    15000.0   60 months     23.99   112000.00      Current
# 9      11979104    16000.0   36 months     16.24   100000.00      Current
# 10     43387337    10000.0   36 months     14.31    91500.00   Fully Paid
# 11     58239238    12000.0   60 months      8.18    55000.00      Current
# ...

# %% [markdown]
# __5.)__ La columna `member_id` representa el identificador de cliente. Busca los clientes con  2 o más créditos.

# %%
loan.head()
# Out:
#    member_id  loan_amnt        term  int_rate  annual_inc loan_status  \
# 0   64972117    25000.0   36 months     13.33     80000.0     Current
# 1   46666131    11200.0   60 months     16.55     31500.0     Current
# 2   66473639     6000.0   36 months     12.69     45000.0     Current
# 3   28500374    10000.0   60 months     12.99     40000.0     Current
# 4     996162     5000.0   36 months     11.49     75000.0  Fully Paid
#
#               purpose addr_state application_type
# 0  debt_consolidation         OH       INDIVIDUAL
# 1  debt_consolidation         CA       INDIVIDUAL
# 2         credit_card         CT       INDIVIDUAL
# 3  debt_consolidation         MI       INDIVIDUAL
# 4  debt_consolidation         TX       INDIVIDUAL

# %%
# Sol:
loans_clientes = loan.member_id.value_counts() 
clientes_2 = loans_clientes[loans_clientes > 1].index.tolist()
clientes_2
# Out:
# [43936191, 49778778, 58973528, 40070464]

# %%
loan[loan.member_id.isin(clientes_2)].sort_values('member_id')
# Out:
#       member_id  loan_amnt        term  int_rate  annual_inc loan_status  \
# 1812   40070464    25000.0   36 months     11.99     95000.0     Current
# 2758   40070464    25000.0   36 months     11.99     95000.0     Current
# 1085   43936191    10000.0   36 months      6.39     60000.0     Current
# 2943   43936191    10000.0   36 months      6.39     60000.0     Current
# 409    49778778    15000.0   36 months     10.99     47000.0     Current
# 2556   49778778    15000.0   36 months     10.99     47000.0     Current
# 1268   58973528    28000.0   60 months     13.33     82600.0     Current
# 2030   58973528    28000.0   60 months     13.33     82600.0     Current
#
#                  purpose addr_state application_type
# 1812  debt_consolidation         NY       INDIVIDUAL
# 2758  debt_consolidation         NY       INDIVIDUAL
# 1085         credit_card         SC       INDIVIDUAL
# 2943         credit_card         SC       INDIVIDUAL
# ...

# %% [markdown]
# __6.)__ Calcular los estadísticos `mínimo`, `máximo`, `media` y `desviación típica` de la columna `int_rate`.

# %%
# Sol:
loan.int_rate.describe()
# Out:
# count    3245.000000
# mean       13.179051
# std         4.345222
# min         5.320000
# 25%         9.990000
# 50%        12.990000
# 75%        15.880000
# max        27.310000
# Name: int_rate, dtype: float64

# %% [markdown]
# __7.)__ Seleccionar los préstamos cuyo importe (valor en la columna `loan_amnt`) sea  mayor  de 33000 euros.

# %%
# Sol:
loan[loan.loan_amnt > 33000]
# Out:
#       member_id  loan_amnt        term  int_rate  annual_inc  \
# 14     59671391    35000.0   60 months     19.99     77457.0
# 21     69504297    35000.0   60 months     18.20     90000.0
# 67     55298110    35000.0   36 months     11.53    135000.0
# 83     71241373    34800.0   60 months     15.41    160000.0
# 84      1224465    35000.0   60 months     19.03    125000.0
# 88     41398853    35000.0   36 months     13.66    115000.0
# 101    43938561    35000.0   36 months     18.84     92000.0
# 112     1415586    35000.0   36 months      9.76    300000.0
# 178    11961629    33425.0   60 months     23.40     80000.0
# 208    49890670    35000.0   36 months      9.17    140000.0
# 277    31216536    35000.0   60 months     12.99    160000.0
# 280    10356875    35000.0   36 months      9.67    190000.0
# 290     4849914    35000.0   36 months     15.31     97000.0
# 371    23913943    35000.0   36 months     12.99    200000.0
# ...

# %% [markdown]
# __8.)__ Representa mediante un histograma el tipo de interés `int_rate`.

# %%
# Sol:
import matplotlib.pyplot as plt
# %matplotlib inline

loan.int_rate.hist();

# %%
# Sol:

# %% [markdown]
# __9.)__ Nos interesa conocer la finalidad de los préstamos (columna `purpose`). Calcula el número de préstamos por finalidad.

# %%
# Sol: 
loan.purpose.unique()
# Out:
# array(['debt_consolidation', 'credit_card', 'car', 'moving', 'other',
#        'home_improvement', 'medical', 'vacation', 'major_purchase',
#        'small_business', 'house', 'educational', 'wedding',
#        'renewable_energy'], dtype=object)

# %%
loan.purpose.value_counts()
# Out:
# debt_consolidation    1926
# credit_card            753
# home_improvement       200
# other                  162
# major_purchase          68
# small_business          31
# car                     25
# medical                 24
# moving                  20
# vacation                16
# house                   11
# wedding                  5
# renewable_energy         3
# educational              1
# Name: purpose, dtype: int64

# %% [markdown]
# __10.)__ Calcula el valor medio del tipo de interés dependiendo de la finalidad del préstamo.

# %%
# Sol: 
import numpy as np
funciones = {'member_id': 'count', 'int_rate': 'mean'}


loan.groupby(by=['purpose']).agg(funciones)
# Out:
#                     member_id   int_rate
# purpose
# car                        25  13.069200
# credit_card               753  11.818367
# debt_consolidation       1926  13.554346
# educational                 1  11.580000
# home_improvement          200  12.612550
# house                      11  15.546364
# major_purchase             68  12.576912
# medical                    24  13.684167
# moving                     20  17.138000
# other                     162  15.071543
# renewable_energy            3   9.593333
# small_business             31  14.556774
# vacation                   16  13.347500
# wedding                     5  13.538000

# %%
loan.groupby(by=['purpose']).int_rate.agg([min, 'mean'])
# Out:
#                       min       mean
# purpose
# car                  5.99  13.069200
# credit_card          5.32  11.818367
# debt_consolidation   5.32  13.554346
# educational         11.58  11.580000
# home_improvement     5.32  12.612550
# house                6.03  15.546364
# major_purchase       5.32  12.576912
# medical              6.03  13.684167
# moving               9.99  17.138000
# other                5.32  15.071543
# renewable_energy     7.49   9.593333
# small_business       7.49  14.556774
# vacation             6.62  13.347500
# wedding              9.62  13.538000

# %% [markdown]
# __11.)__ En cuanto a la duración del préstamo, columna `term`,  nos encontramos con préstamos a 36 meses y 60 meses.

# %%
loan.term.value_counts()
# Out:
#  36 months    2313
#  60 months     932
# Name: term, dtype: int64

# %% [markdown]
# Transforma dicha columna de forma que no contenga valores de tipo `str`, sino de tipo `int`, es decir:
# * valor 36 en lugar de ' 36 months'
# * valor 60 en lugar de ' 60 months'

# %%
# Sol: 
import re
patron = '[0-9]+'
re.findall(patron, 'concedido a 36 meses')
# Out:
# ['36']

# %%
loan.term = loan.term.map(lambda text: float(re.findall(patron, text)[0]))

# %%
loan.head()
# Out:
#    member_id  loan_amnt  term  int_rate  annual_inc loan_status  \
# 0   64972117    25000.0  36.0     13.33     80000.0     Current
# 1   46666131    11200.0  60.0     16.55     31500.0     Current
# 2   66473639     6000.0  36.0     12.69     45000.0     Current
# 3   28500374    10000.0  60.0     12.99     40000.0     Current
# 4     996162     5000.0  36.0     11.49     75000.0  Fully Paid
#
#               purpose addr_state application_type
# 0  debt_consolidation         OH       INDIVIDUAL
# 1  debt_consolidation         CA       INDIVIDUAL
# 2         credit_card         CT       INDIVIDUAL
# 3  debt_consolidation         MI       INDIVIDUAL
# 4  debt_consolidation         TX       INDIVIDUAL

# %%
d = { ' 36 months' : 36, ' 60 months' : 60} 
loan.term.map(d)
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
#         ..
# 3215   NaN
# 3216   NaN
# 3217   NaN
# 3218   NaN
# 3219   NaN
# 3220   NaN
# 3221   NaN
# 3222   NaN
# 3223   NaN
# 3224   NaN
# 3225   NaN
# 3226   NaN
# 3227   NaN
# 3228   NaN
# 3229   NaN
# 3230   NaN
# 3231   NaN
# 3232   NaN
# 3233   NaN
# 3234   NaN
# 3235   NaN
# 3236   NaN
# 3237   NaN
# 3238   NaN
# 3239   NaN
# 3240   NaN
# 3241   NaN
# 3242   NaN
# 3243   NaN
# 3244   NaN
# Name: term, Length: 3245, dtype: float64

# %%
loan.term.str.replace('36 months', '36')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-2c25e99fb265> in <module>()
# ----> 1 loan.term.str.replace('36 months', '36')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370         if (name in self._internal_names_set or name in self._metadata or
#    4371                 name in self._accessors):
# -> 4372             return object.__getattribute__(self, name)
#    4373         else:
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     131             # we're accessing the attribute of the class, i.e., Dataset.geo
#     132             return self._accessor
# --> 133         accessor_obj = self._accessor(obj)
#     134         # Replace the property with the accessor object. Inspired by:
# ...

# %%
d

# %% [markdown]
# __12.)__  Calcula de la correlación entre la cantidad prestada `loan_amnt`, renta `annual_inc` y el tipo de interés `int_rate`.

# %%
# Sol: 
loan.loc[:, ['loan_amnt', 'annual_inc', 'int_rate']].corr()
# Out:
#             loan_amnt  annual_inc  int_rate
# loan_amnt    1.000000    0.160888  0.133690
# annual_inc   0.160888    1.000000 -0.036418
# int_rate     0.133690   -0.036418  1.000000

# %% [markdown]
# __13.)__ La columna `loan_status` aporta información del estado del préstamo.
# * Consulta los diferentes estados que nos podemos encontrar en el dataset.

# %%
# Sol: 
peso = loan.loan_status.value_counts() / len(loan) * 100
peso.name = 'peso'

# %%
pd.concat([peso, loan.loan_status.value_counts() ], 
          axis=1)
# Out:
#                                                          peso  loan_status
# Current                                             67.457627         2189
# Fully Paid                                          23.636364          767
# Charged Off                                          5.269646          171
# Late (31-120 days)                                   1.171032           38
# Issued                                               0.955316           31
# In Grace Period                                      0.739599           24
# Late (16-30 days)                                    0.308166           10
# Does not meet the credit policy. Status:Fully Paid   0.246533            8
# Does not meet the credit policy. Status:Charged...   0.154083            5
# Default                                              0.061633            2

# %% [markdown]
# * Calcula el peso que tiene cada estado con respecto al total de créditos.

# %%
# Sol: 
loan.shape
# Out:
# (3245, 9)

# %%
tabla = pd.DataFrame([t, peso])
tabla.T
# Out:
#                                                     loan_status       Peso
# Current                                                  2189.0  67.457627
# Fully Paid                                                767.0  23.636364
# Charged Off                                               171.0   5.269646
# Late (31-120 days)                                         38.0   1.171032
# Issued                                                     31.0   0.955316
# In Grace Period                                            24.0   0.739599
# Late (16-30 days)                                          10.0   0.308166
# Does not meet the credit policy. Status:Fully Paid          8.0   0.246533
# Does not meet the credit policy. Status:Charged...          5.0   0.154083
# Default                                                     2.0   0.061633

# %% [markdown]
# * El estado Current representan préstamos en proceso. Queremos centranos en el resto. Selecciona los préstamos cuyo estado es distinto de current.

# %%
# Sol: 
activos = loan[loan.loan_status != 'Current'].copy()
activos.head()
# Out:
#     member_id  loan_amnt  term  int_rate  annual_inc  loan_status  \
# 4      996162     5000.0  36.0     11.49     75000.0   Fully Paid
# 10   43387337    10000.0  36.0     14.31     91500.0   Fully Paid
# 16    1741580    12000.0  36.0     12.12     40000.0   Fully Paid
# 18    8126823    10000.0  36.0     22.20     61000.0  Charged Off
# 28   61874363     2400.0  36.0     18.25     60000.0   Fully Paid
#
#                purpose addr_state application_type
# 4   debt_consolidation         TX       INDIVIDUAL
# 10              moving         GA       INDIVIDUAL
# 16  debt_consolidation         NY       INDIVIDUAL
# 18  debt_consolidation         NC       INDIVIDUAL
# 28  debt_consolidation         NC       INDIVIDUAL

# %% [markdown]
# * Con el resultado del punto anterior, clasificar los préstamos en dos categorías. Crear una columna nueva llamada Charged Off que indique si el préstamo es Charged Off o no.

# %%
# Sol: 
activos['Charged Off'] = activos.loan_status == 'Charged Off'
activos.tail()
# Out:
#       member_id  loan_amnt  term  int_rate  annual_inc loan_status  \
# 3227   10781976     6000.0  36.0      8.90     59000.0  Fully Paid
# 3230    6467089     8400.0  36.0     14.09     26000.0  Fully Paid
# 3235   12667800    27300.0  60.0     23.40    110000.0  Fully Paid
# 3237   18565649    18000.0  36.0      7.69     92000.0  Fully Paid
# 3239    1966440    20000.0  36.0     19.72     60000.0  Fully Paid
#
#                  purpose addr_state application_type  Charged Off
# 3227  debt_consolidation         OH       INDIVIDUAL        False
# 3230         credit_card         CA       INDIVIDUAL        False
# 3235               other         NY       INDIVIDUAL        False
# 3237  debt_consolidation         PA       INDIVIDUAL        False
# 3239         credit_card         OR       INDIVIDUAL        False

# %%
# Sol: 
activos['Charged Off'] = activos.loan_status.map(lambda x: x == 'Charged Off')
activos.head(2)
# Out:
#     member_id  loan_amnt  term  int_rate  annual_inc loan_status  \
# 4      996162     5000.0  36.0     11.49     75000.0  Fully Paid
# 10   43387337    10000.0  36.0     14.31     91500.0  Fully Paid
#
#                purpose addr_state application_type  Charged Off
# 4   debt_consolidation         TX       INDIVIDUAL        False
# 10              moving         GA       INDIVIDUAL        False

# %% [markdown]
# __14.)__ Importe del préstamo (loan_amnt): a cada uno de los préstamos le asignaremos una categoría dependiento del importe del préstamo:
#
# * low (importe < 8000)
# * medium-low, (importe < 13000),
# * medium-high, (importe < 18000)
# * high (resto)
#
#
# Diseñar una función `clasificar_cantidad` que devuelva una categoría para un importe dado de entrada.
#
# Añadir una nueva columna a la tabla de préstamos con información de la categoría.

# %%
# Sol: 
clasificar_cantidad1 = lambda x: 'low' if x < 8000 else    \
                      ('medium-low' if x < 13000 else     \
                      ('medium-high' if x < 18000 else 'high'))

# %%
def clasificar_cantidad2(x):
    if x < 8000:
        return 'low'
    elif x < 13000:
        return 'medium-low'
    elif x < 18000:
        return 'medium-high' 
    else:
        return 'high'

# %%
activos['Tipo'] = activos.loan_amnt.apply(clasificar_cantidad2)
activos.head()
# Out:
#     member_id  loan_amnt  term  int_rate  annual_inc  loan_status  \
# 4      996162     5000.0  36.0     11.49     75000.0   Fully Paid
# 10   43387337    10000.0  36.0     14.31     91500.0   Fully Paid
# 16    1741580    12000.0  36.0     12.12     40000.0   Fully Paid
# 18    8126823    10000.0  36.0     22.20     61000.0  Charged Off
# 28   61874363     2400.0  36.0     18.25     60000.0   Fully Paid
#
#                purpose addr_state application_type  Charged Off        Tipo
# 4   debt_consolidation         TX       INDIVIDUAL        False         low
# 10              moving         GA       INDIVIDUAL        False  medium-low
# 16  debt_consolidation         NY       INDIVIDUAL        False  medium-low
# 18  debt_consolidation         NC       INDIVIDUAL         True  medium-low
# 28  debt_consolidation         NC       INDIVIDUAL        False         low
